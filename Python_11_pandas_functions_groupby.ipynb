# %% [markdown]
# # Функции в Pandas
# Примеры из презентации

# %%
import pandas as pd

# %%
df = pd.DataFrame({'user_id': [1, 2, 3], 'clicks': [163, 130, 97], 'orders': [2, 4, 0]})
df
# Out:
#    user_id  clicks  orders
# 0        1     163       2
# 1        2     130       4
# 2        3      97       0

# %%
df = pd.DataFrame({'user_id': [1, 2, 3], 'clicks': [163, 130, 97], 'orders': [2, 4, 0], 'calculated': [False, False, True]})
df[['user_id', 'clicks', 'orders', 'calculated']]
# Out:
#    user_id  clicks  orders  calculated
# 0        1     163       2       False
# 1        2     130       4       False
# 2        3      97       0        True

# %%
def watcher(param):
    """Мне только посмотреть"""
    return param == 0

# %%
df['watcher'] = df['orders'].apply(watcher)
df
# Out:
#    user_id  clicks  orders  calculated  watcher
# 0        1     163       2       False    False
# 1        2     130       4       False    False
# 2        3      97       0        True     True

# %% [markdown]
# Применяем метод apply к одному столбцу. Сейчас в переменную функции передаются значения одного столбца

# %%
def conversion(row):
    """Подсчет конверсии переходов в покупки"""
    return row['orders'] / row['clicks']

# %% [markdown]
# ### Как потестировать функцию со значениями одной строки

# %%
row1 = pd.DataFrame({'clicks': [163], 
                     'orders': [2], 
                     'user_id': [1]})
conversion(row1)
# Out:
# 0    0.01227
# dtype: float64

# %% [markdown]
# Применяем метод apply к датафрейму. В переменную функции передаются строки целиком

# %%
df = pd.DataFrame({'user_id': [1, 2, 3], 'clicks': [163, 130, 97], 'orders': [2, 4, 0]})
df[['user_id', 'clicks', 'orders']]
# Out:
#    user_id  clicks  orders
# 0        1     163       2
# 1        2     130       4
# 2        3      97       0

# %%
df['conversion'] = df.apply(conversion, axis=1)

# %%
df[['user_id', 'clicks', 'orders', 'conversion']]
# Out:
#    user_id  clicks  orders  conversion
# 0        1     163       2    0.012270
# 1        2     130       4    0.030769
# 2        3      97       0    0.000000

# %% [markdown]
# ### Анализ рекламных кампаний

# %%
import pandas as pd

# %%
stats = pd.read_excel('ad_campaigns.xlsx')
stats.head()
# Out:
#      Название группы                            Фраза (с минус-словами)  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    Продуктивность  ID объявления                      Заголовок  \
# 0             4.5     2101704995  МРТ на Менделеевской от 2000₽
# 1             4.5     2101704995  МРТ на Менделеевской от 2000₽
# 2             7.4     2101704995  МРТ на Менделеевской от 2000₽
# 3             5.0     2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4             5.0     2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                Текст  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                               Ссылка
# 0  https://awesome-site.ru/?utm_source=yandex&utm...
# 1  https://awesome-site.ru/?utm_source=yandex&utm...
# 2  https://awesome-site.ru/?utm_source=yandex&utm...
# 3  https://awesome-site.ru/?utm_source=yandex&utm...
# 4  https://awesome-site.ru/?utm_source=yandex&utm...

# %%
stats.columns = ['group', 'phrase', 'effect', 'ad_id', 'title', 'text', 'link']
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link
# 0  https://awesome-site.ru/?utm_source=yandex&utm...
# 1  https://awesome-site.ru/?utm_source=yandex&utm...
# 2  https://awesome-site.ru/?utm_source=yandex&utm...
# 3  https://awesome-site.ru/?utm_source=yandex&utm...
# 4  https://awesome-site.ru/?utm_source=yandex&utm...

# %% [markdown]
# ### Lambda-функции
# Хотим посчитать распределение количества слов в столбце с фразами

# %%
phrase = 'МРТ на Менделеевской от 2000'

# %%
len(phrase.split(' '))
# Out:
# 5

# %%
stats['word_count'] = stats['phrase'].apply(lambda word: len(word.split(' ')))
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link  word_count
# 0  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 1  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 2  https://awesome-site.ru/?utm_source=yandex&utm...           6
# 3  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 4  https://awesome-site.ru/?utm_source=yandex&utm...           2

# %%
# вариант с передачей всей строчки функции
# тут надо обязательно указать параметр axis = 1

stats['word_count'] = stats.apply(lambda x: len(x['phrase'].split(' ')), axis=1)
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link  word_count
# 0  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 1  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 2  https://awesome-site.ru/?utm_source=yandex&utm...           6
# 3  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 4  https://awesome-site.ru/?utm_source=yandex&utm...           2

# %% [markdown]
# ### Упражнение
# Напишите отдельную функцию word_count, которая считает количество слов в столбце phrase. Функцию можно применять как к столбцу phrase, так и к строке целиком.

# %%
words = []
new_words_count = []
def word_count():
    for row in stats['phrase']:
        words = len(row.split(' '))
        new_words_count.append(words)
word_count()
stats["new_words_count"] = new_words_count
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link  word_count  \
# 0  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 1  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 2  https://awesome-site.ru/?utm_source=yandex&utm...           6
# 3  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 4  https://awesome-site.ru/?utm_source=yandex&utm...           2
#
#    new_words_count
# 0                2
# 1                2
# 2                6
# 3                2
# 4                2

# %% [markdown]
# ######**Для проверки правильности работы решил добавить новый столбец "new_words_count" для своей функции вместо перезаписи уже существующего word_count.**

# %% [markdown]
# ### Произвольные функции
# В URL кампаний есть названия. С этим надо что-то делать

# %%
# обращение к индексу и значениям Series
res = stats.word_count.value_counts()
res
# Out:
# 3     1129
# 4      529
# 2      189
# 5      137
# 6       84
# 7       38
# 8       30
# 9       12
# 10       6
# 12       2
# 11       1
# 17       1
# 21       1
# Name: word_count, dtype: int64

# %%
#res = stats.new_words_count.value_counts()
#res

# %%
res.index[0]
# Out:
# 3

# %%
res.values[0]
# Out:
# 1129

# %%
# пример ссылки
url = stats.loc[0, 'link']
url
# Out:
# 'https://awesome-site.ru/?utm_source=yandex&utm_medium=cpc&utm_campaign=a825749b87&utm_content=dev_{device_type}'

# %%
from urllib import parse

# %%
parse.urlsplit('https://ya.ru/news/sport?search=footbal#abc')
# Out:
# SplitResult(scheme='https', netloc='ya.ru', path='/news/sport', query='search=footbal', fragment='abc')

# %%
parsed = parse.urlsplit(url)
parsed
# Out:
# SplitResult(scheme='https', netloc='awesome-site.ru', path='/', query='utm_source=yandex&utm_medium=cpc&utm_campaign=a825749b87&utm_content=dev_{device_type}', fragment='')

# %%
# можно конечно вручную
parsed.query.split('&')[2].split('=')[1]
# Out:
# 'a825749b87'

# %%
# как доставать значения

parsed.netloc
# Out:
# 'awesome-site.ru'

# %%
params = parse.parse_qs(parsed.query)
params
# Out:
# {'utm_source': ['yandex'],
#  'utm_medium': ['cpc'],
#  'utm_campaign': ['a825749b87'],
#  'utm_content': ['dev_{device_type}']}

# %%
# вот и кампании

params['utm_campaign'][0]
# Out:
# 'a825749b87'

# %%
# зачем тут везде списки?

url_with_doubles = 'https://awesome-site.ru/?a=1&a=2&a=3'

parsed = parse.urlsplit(url_with_doubles)
parse.parse_qs(parsed.query)
# Out:
# {'a': ['1', '2', '3']}

# %%
# оборачиваем все в функцию
# в качестве аргумента будет строка датафрейма

def campaign_name(row):
    """Получение названия кампании из ссылки внутри строки row"""

    parsed = parse.urlsplit(row['link'])
    params_dict = parse.parse_qs(parsed.query)

    return params_dict['utm_campaign'][0]

# %%
# проверяем датафрейм
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link  word_count  \
# 0  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 1  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 2  https://awesome-site.ru/?utm_source=yandex&utm...           6
# 3  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 4  https://awesome-site.ru/?utm_source=yandex&utm...           2
#
#    new_words_count
# 0                2
# 1                2
# 2                6
# 3                2
# 4                2

# %%
stats['campaign'] = stats.apply(campaign_name, axis=1)
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link  word_count  \
# 0  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 1  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 2  https://awesome-site.ru/?utm_source=yandex&utm...           6
# 3  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 4  https://awesome-site.ru/?utm_source=yandex&utm...           2
#
#    new_words_count    campaign
# 0                2  a825749b87
# 1                2  a825749b87
# 2                6  a825749b87
# 3                2  9cc0c5f6ca
# 4                2  9cc0c5f6ca

# %% [markdown]
# ### Как передать в функцию несколько аргументов

# %%
# как передать несколько аргументов

def power_up(row, n):
    """Возводит значение столбца effect в степень n"""
    return row['effect'] ** n

# %%
stats['power_up'] = stats.apply(power_up, n=3, axis=1)
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link  word_count  \
# 0  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 1  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 2  https://awesome-site.ru/?utm_source=yandex&utm...           6
# 3  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 4  https://awesome-site.ru/?utm_source=yandex&utm...           2
#
#    new_words_count    campaign  power_up
# 0                2  a825749b87    91.125
# 1                2  a825749b87    91.125
# 2                6  a825749b87   405.224
# 3                2  9cc0c5f6ca   125.000
# 4                2  9cc0c5f6ca   125.000

# %% [markdown]
# ### Упражнение
# В наших данных есть много объявлений с услугой МРТ (в столбце group есть слово 'мрт') круглосуточно (в тексте объявления text есть '24 часа'). Отфильтруйте строки, в которых НЕ упоминается МРТ, но прием идет круглосуточно. Сколько таких строк в датасете?

# %%
len(stats['group'])
# Out:
# 2159

# %%
stats['text'].value_counts()
# Out:
# 24 часа. МРТ в день обращения. Консультация врача бесплатно. Без очередей.    1541
# 24 часа. МРТ в день обращения. Консультация врача бесплатно. Без очередей      549
# 24 часа. От 2 000₽. Консультация врача бесплатно. Без очередей                  39
# 24 часа. От 2 000₽. Консультация врача бесплатно. Без очередей.                 30
# Name: text, dtype: int64

# %% [markdown]
# ***Сперва найдем в скольких строках столбца "group" имеется слово мрт***

# %%
stats_with_mrt = stats[stats['group'].str.contains('мрт')]
stats_with_mrt
# Out:
#                    group                                             phrase  \
# 0      мрт менделеевская                              "!мрт !менделеевская"
# 1                мрт цао                                "мрт менделеевская"
# 2                мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3                мрт цао                                        "!мрт !цао"
# 4                мрт сао                                          "мрт цао"
# ...                  ...                                                ...
# 2154          мрт палиха                                         "мрт вднх"
# 2155  клиника москва мрт  мрт вднх -головы -касаткина -позвоночника -сде...
# 2156  клиника москва мрт  мрт палиха -10 -головы -позвоночника -сделать ...
# 2157  клиника москва мрт                               "клиника москва мрт"
# 2158       10 мрт палиха                            "!клиника !москва !мрт"
#
#       effect       ad_id                           title  \
# 0        4.5  2101704995   МРТ на Менделеевской от 2000₽
# 1        4.5  2101704995   МРТ на Менделеевской от 2000₽
# 2        7.4  2101704995   МРТ на Менделеевской от 2000₽
# 3        5.0  2101704999    МРТ в ЦАО от 2000₽. Звоните!
# 4        5.0  2101704999    МРТ в ЦАО от 2000₽. Звоните!
# ...      ...         ...                             ...
# 2154     7.4  3826704858   МРТ на ВДНХ в Москве от 2000₽
# 2155     7.2  3826704858   МРТ на ВДНХ в Москве от 2000₽
# 2156     7.4  3826704860     МРТ на ул. Палиха от 2 000₽
# 2157     8.7  3826704862  Клиники МРТ в Москве. От 2000₽
# 2158     8.7  3826704862  Клиники МРТ в Москве. От 2000₽
#
#                                                    text  \
# 0     24 часа. МРТ в день обращения. Консультация вр...
# 1     24 часа. МРТ в день обращения. Консультация вр...
# 2     24 часа. МРТ в день обращения. Консультация вр...
# 3     24 часа. МРТ в день обращения. Консультация вр...
# 4     24 часа. МРТ в день обращения. Консультация вр...
# ...                                                 ...
# 2154  24 часа. МРТ в день обращения. Консультация вр...
# 2155  24 часа. МРТ в день обращения. Консультация вр...
# 2156  24 часа. МРТ в день обращения. Консультация вр...
# 2157  24 часа. МРТ в день обращения. Консультация вр...
# 2158  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                    link  word_count  \
# 0     https://awesome-site.ru/?utm_source=yandex&utm...           2
# 1     https://awesome-site.ru/?utm_source=yandex&utm...           2
# 2     https://awesome-site.ru/?utm_source=yandex&utm...           6
# 3     https://awesome-site.ru/?utm_source=yandex&utm...           2
# 4     https://awesome-site.ru/?utm_source=yandex&utm...           2
# ...                                                 ...         ...
# 2154  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 2155  https://awesome-site.ru/?utm_source=yandex&utm...           8
# 2156  https://awesome-site.ru/?utm_source=yandex&utm...           9
# 2157  https://awesome-site.ru/?utm_source=yandex&utm...           3
# 2158  https://awesome-site.ru/?utm_source=yandex&utm...           3
#
#       new_words_count    campaign
# 0                   2  a825749b87
# 1                   2  a825749b87
# 2                   6  a825749b87
# 3                   2  9cc0c5f6ca
# 4                   2  9cc0c5f6ca
# ...               ...         ...
# 2154                2  9bf072c32b
# 2155                8  9bf072c32b
# 2156                9  a117c5fc1b
# 2157                3  23d6da5a5a
# 2158                3  23d6da5a5a
#
# [2120 rows x 10 columns]

# %% [markdown]
# **Изначальный размер датасета составлял 2159 строк. После нахождения всех строк с "мрт" в стоблце group получаем 2120 оставшихся строк и записываем их в новый датасет.
# Далее объединим два датасета.**

# %%
stats_without_mrt = pd.concat([stats, stats_with_mrt], axis = 0, ignore_index = True)
len(stats_without_mrt)
# Out:
# 4279

# %% [markdown]
# **Получаем 4279 строк в датасете. Сумма строк двух датасетов совпадает. Далее были удалены одинаковые строки, следовательно у нас останется датасет без вхождения мрт в столбце group.**

# %%
stats_without_mrt = stats_without_mrt.drop_duplicates(keep=False)
stats_without_mrt.reset_index().head(5)
# Out:
#    index                    group  \
# 0   1570  перово томография центр
# 1   1571  перово томография центр
# 2   1572  перово томография центр
# 3   1573          свао томография
# 4   1574          свао томография
#
#                                               phrase  effect       ad_id  \
# 0  на мрт щукинский -голова -позвоночника -сделат...     6.6  2428554709
# 1                     "!на !сиреневом !бульвар !мрт"     1.8  2428554711
# 2                            перово томография центр     7.7  2428554713
# 3                       "!перово !томография !центр"     3.3  2428554713
# 4                          "перово томография центр"     4.8  2428554713
#
#                            title  \
# 0  МРТ центры в Москве. От 2000₽
# 1  МРТ центры в Москве. От 2000₽
# 2  МРТ центры в Москве. От 2000₽
# 3  МРТ центры в Москве. От 2000₽
# 4  МРТ центры в Москве. От 2000₽
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link  word_count  \
# 0  https://awesome-site.ru/?utm_source=yandex&utm...           8
# 1  https://awesome-site.ru/?utm_source=yandex&utm...           4
# 2  https://awesome-site.ru/?utm_source=yandex&utm...           3
# 3  https://awesome-site.ru/?utm_source=yandex&utm...           3
# 4  https://awesome-site.ru/?utm_source=yandex&utm...           3
#
#    new_words_count    campaign
# 0                8  8e77a0e565
# 1                4  8e77a0e565
# 2                3  8e77a0e565
# 3                3  8e77a0e565
# 4                3  8e77a0e565

# %%
print(f'Всего осталось {len(stats_without_mrt)} строк в которых не содержится слово "мрт" в столбце group. Проверка на 24 часа в столбце text не является необходимой, поскольку не существует ни единой строки без этой надписи.')
# Out:
# Всего осталось 39 строк в которых не содержится слово "мрт" в столбце group. Проверка на 24 часа в столбце text не является необходимой, поскольку не существует ни единой строки без этой надписи.

# %% [markdown]
# # Группировки

# %%
df = pd.DataFrame({'order_id': [1, 2, 3, 4, 5], 'country': ['Россия', 'Китай', 'Китай', 'Россия', 'Россия'], 
                   'category': ['Электроника', 'Авто', 'Электроника', 'Авто', 'Авто'], 
                   'amount': [100, 80, 90, 140, 90]})
df
# Out:
#    order_id country     category  amount
# 0         1  Россия  Электроника     100
# 1         2   Китай         Авто      80
# 2         3   Китай  Электроника      90
# 3         4  Россия         Авто     140
# 4         5  Россия         Авто      90

# %% [markdown]
# Создадим датафрейм df_russia, в котором оставим заказы из России. И аналогично df_china (заказы из Китая).

# %%
df_russia = df[ (df['country']=='Россия')]
df_russia
# Out:
#    order_id country     category  amount
# 0         1  Россия  Электроника     100
# 3         4  Россия         Авто     140
# 4         5  Россия         Авто      90

# %%
df_china = df[(df['country'] == 'Китай')]
df_china
# Out:
#    order_id country     category  amount
# 1         2   Китай         Авто      80
# 2         3   Китай  Электроника      90

# %% [markdown]
# Посчитаем для df_russia и df_china:
# - среднюю стоимость заказа
# - разницу между максимальной и минимальной стоимостью заказа

# %%
df_russia['amount'].mean()
# Out:
# 110.0

# %%
df_china['amount'].mean()
# Out:
# 85.0

# %%
df_russia['amount'].max() - df_russia['amount'].min()
# Out:
# 50

# %%
df_china['amount'].max() - df_china['amount'].min()
# Out:
# 10

# %% [markdown]
# Объединим процесс разбиения на датафреймы

# %%
def groupby_function(data):
    return data.amount.max() - data.amount.min()

# %%
df.groupby('country').apply(groupby_function)
# Out:
# country
# Китай     10
# Россия    50
# dtype: int64

# %% [markdown]
# Вернемся к статистике рекламных кампаний

# %%
# раньше использовали value_counts

stats['campaign'].value_counts().head()
# Out:
# 7f35591a28    456
# 8e77a0e565    348
# 2cc2e7d770    240
# f6d2ae1e3d    220
# e90f4db55a    218
# Name: campaign, dtype: int64

# %%
# более универсальный способ

stats.groupby('campaign').count().head()
# Out:
#             group  phrase  effect  ad_id  title  text  link  word_count  \
# campaign
# 034ada41b6      3       3       3      3      3     3     3           3
# 03fcaecd1d      2       2       2      2      2     2     2           2
# 0697a81555      2       2       2      2      2     2     2           2
# 08cdcb57a3      3       3       3      3      3     3     3           3
# 0f0ba311fb      2       2       2      2      2     2     2           2
#
#             new_words_count
# campaign
# 034ada41b6                3
# 03fcaecd1d                2
# 0697a81555                2
# 08cdcb57a3                3
# 0f0ba311fb                2

# %%
stats.groupby('campaign').count()[['group', 'effect']].head()
# Out:
#             group  effect
# campaign
# 034ada41b6      3       3
# 03fcaecd1d      2       2
# 0697a81555      2       2
# 08cdcb57a3      3       3
# 0f0ba311fb      2       2

# %% [markdown]
# ### Как вернуть столбец из индекса - метод reset_index()

# %%
stats.groupby('campaign').count().reset_index()
# Out:
#        campaign  group  phrase  effect  ad_id  title  text  link  word_count  \
# 0    034ada41b6      3       3       3      3      3     3     3           3
# 1    03fcaecd1d      2       2       2      2      2     2     2           2
# 2    0697a81555      2       2       2      2      2     2     2           2
# 3    08cdcb57a3      3       3       3      3      3     3     3           3
# 4    0f0ba311fb      2       2       2      2      2     2     2           2
# ..          ...    ...     ...     ...    ...    ...   ...   ...         ...
# 110  f6d2ae1e3d    220     220     220    220    220   220   220         220
# 111  f80e902d76      1       1       1      1      1     1     1           1
# 112  fbed7afb58      3       3       3      3      3     3     3           3
# 113  fe6fa9154a      2       2       2      2      2     2     2           2
# 114  fedd9b9cc0      2       2       2      2      2     2     2           2
#
#      new_words_count
# 0                  3
# 1                  2
# 2                  2
# 3                  3
# 4                  2
# ..               ...
# 110              220
# 111                1
# 112                3
# 113                2
# 114                2
#
# [115 rows x 10 columns]

# %% [markdown]
# ### К группировке можно применять разные функции такие образом:

# %%
obj = stats.groupby('campaign')
obj.head()
# Out:
#                    group                                             phrase  \
# 0      мрт менделеевская                              "!мрт !менделеевская"
# 1                мрт цао                                "мрт менделеевская"
# 2                мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3                мрт цао                                        "!мрт !цао"
# 4                мрт сао                                          "мрт цао"
# ...                  ...                                                ...
# 2154          мрт палиха                                         "мрт вднх"
# 2155  клиника москва мрт  мрт вднх -головы -касаткина -позвоночника -сде...
# 2156  клиника москва мрт  мрт палиха -10 -головы -позвоночника -сделать ...
# 2157  клиника москва мрт                               "клиника москва мрт"
# 2158       10 мрт палиха                            "!клиника !москва !мрт"
#
#       effect       ad_id                           title  \
# 0        4.5  2101704995   МРТ на Менделеевской от 2000₽
# 1        4.5  2101704995   МРТ на Менделеевской от 2000₽
# 2        7.4  2101704995   МРТ на Менделеевской от 2000₽
# 3        5.0  2101704999    МРТ в ЦАО от 2000₽. Звоните!
# 4        5.0  2101704999    МРТ в ЦАО от 2000₽. Звоните!
# ...      ...         ...                             ...
# 2154     7.4  3826704858   МРТ на ВДНХ в Москве от 2000₽
# 2155     7.2  3826704858   МРТ на ВДНХ в Москве от 2000₽
# 2156     7.4  3826704860     МРТ на ул. Палиха от 2 000₽
# 2157     8.7  3826704862  Клиники МРТ в Москве. От 2000₽
# 2158     8.7  3826704862  Клиники МРТ в Москве. От 2000₽
#
#                                                    text  \
# 0     24 часа. МРТ в день обращения. Консультация вр...
# 1     24 часа. МРТ в день обращения. Консультация вр...
# 2     24 часа. МРТ в день обращения. Консультация вр...
# 3     24 часа. МРТ в день обращения. Консультация вр...
# 4     24 часа. МРТ в день обращения. Консультация вр...
# ...                                                 ...
# 2154  24 часа. МРТ в день обращения. Консультация вр...
# 2155  24 часа. МРТ в день обращения. Консультация вр...
# 2156  24 часа. МРТ в день обращения. Консультация вр...
# 2157  24 часа. МРТ в день обращения. Консультация вр...
# 2158  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                    link  word_count  \
# 0     https://awesome-site.ru/?utm_source=yandex&utm...           2
# 1     https://awesome-site.ru/?utm_source=yandex&utm...           2
# 2     https://awesome-site.ru/?utm_source=yandex&utm...           6
# 3     https://awesome-site.ru/?utm_source=yandex&utm...           2
# 4     https://awesome-site.ru/?utm_source=yandex&utm...           2
# ...                                                 ...         ...
# 2154  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 2155  https://awesome-site.ru/?utm_source=yandex&utm...           8
# 2156  https://awesome-site.ru/?utm_source=yandex&utm...           9
# 2157  https://awesome-site.ru/?utm_source=yandex&utm...           3
# 2158  https://awesome-site.ru/?utm_source=yandex&utm...           3
#
#       new_words_count    campaign
# 0                   2  a825749b87
# 1                   2  a825749b87
# 2                   6  a825749b87
# 3                   2  9cc0c5f6ca
# 4                   2  9cc0c5f6ca
# ...               ...         ...
# 2154                2  9bf072c32b
# 2155                8  9bf072c32b
# 2156                9  a117c5fc1b
# 2157                3  23d6da5a5a
# 2158                3  23d6da5a5a
#
# [339 rows x 10 columns]

# %%
obj.max().head()
# Out:
#                                      group  \
# campaign
# 034ada41b6           в недорого москва мрт
# 03fcaecd1d       сделать мрт сущевский вал
# 0697a81555  мрт позвоночника сущевский вал
# 08cdcb57a3                         мрт сао
# 0f0ba311fb         сделать мрт октябрьский
#
#                                                        phrase  effect  \
# campaign
# 034ada41b6            в москве открытого типа адрес мрт -цена     9.0
# 03fcaecd1d                              сделать мрт стромынка     6.5
# 0697a81555                         мрт позвоночника стромынка     5.5
# 08cdcb57a3  мрт сао -головы -москве -позвоночника -сделать...     7.4
# 0f0ba311fb                         сделать мрт новослободская     6.4
#
#                  ad_id                              title  \
# campaign
# 034ada41b6  2428554779  Адрес МРТ открытого типа в Москве
# 03fcaecd1d  2101705759     Сделайте МРТ на ул. Стромынка!
# 0697a81555  2101706415  МРТ позвоночника на ул. Стромынка
# 08cdcb57a3  2101705000       МРТ в САО от 2000₽. Звоните!
# 0f0ba311fb  2101705726     Сделайте МРТ на Новослободской
#
#                                                          text  \
# campaign
# 034ada41b6  24 часа. От 2 000₽. Консультация врача бесплат...
# 03fcaecd1d  24 часа. От 2 000₽. Консультация врача бесплат...
# 0697a81555  24 часа. От 2 000₽. Консультация врача бесплат...
# 08cdcb57a3  24 часа. МРТ в день обращения. Консультация вр...
# 0f0ba311fb  24 часа. От 2 000₽. Консультация врача бесплат...
#
#                                                          link  word_count  \
# campaign
# 034ada41b6  https://awesome-site.ru/?utm_source=yandex&utm...           7
# 03fcaecd1d  https://awesome-site.ru/?utm_source=yandex&utm...           3
# 0697a81555  https://awesome-site.ru/?utm_source=yandex&utm...           3
# 08cdcb57a3  https://awesome-site.ru/?utm_source=yandex&utm...           7
# 0f0ba311fb  https://awesome-site.ru/?utm_source=yandex&utm...           3
#
#             new_words_count
# campaign
# 034ada41b6                7
# 03fcaecd1d                3
# 0697a81555                3
# 08cdcb57a3                7
# 0f0ba311fb                3

# %%
obj['effect'].mean().head()
# Out:
# campaign
# 034ada41b6    7.200000
# 03fcaecd1d    5.250000
# 0697a81555    4.750000
# 08cdcb57a3    6.133333
# 0f0ba311fb    5.400000
# Name: effect, dtype: float64

# %% [markdown]
# Для каждой кампании campaign найдем минимальное значение столбца effect и построим рейтинг кампаний по этим значениям, начиная с самого низкого.

# %%
stats3 = stats.drop_duplicates(subset=['campaign', 'effect'])

# %%
stats3['campaign'].value_counts()
# Out:
# 8e77a0e565    41
# 7f35591a28    41
# 2cc2e7d770    33
# 7388fb4c7b    22
# be97523396    22
#               ..
# 63153306ff     1
# 22797af531     1
# e2e45b2b2a     1
# 28d8dca4df     1
# 23d6da5a5a     1
# Name: campaign, Length: 115, dtype: int64

# %%
stats3.groupby('effect')['campaign'].min()
# Out:
# effect
# 1.6    8e77a0e565
# 1.7    7f35591a28
# 1.8    7f35591a28
# 1.9    1a39ecc6ce
# 2.0    8d3a748298
#           ...
# 8.6    55188f1274
# 8.7    23d6da5a5a
# 8.8    41af22f2cc
# 9.0    034ada41b6
# 9.3    88dfb2a17b
# Name: campaign, Length: 74, dtype: object

# %%
stats3 = stats.drop_duplicates(subset=['campaign', 'effect'])
stats4 = stats3.sort_values(by=['effect'], ascending=True)
stats4
# Out:
#                                                group  \
# 1578                          семеновский томография
# 404   мрт на алексеевской кулаков переулок 13 отзывы
# 2137                                 мрт на шолохова
# 344                         мрт иваньковское шоссе 3
# 604               сделать мрт в районе ул лобненская
# ...                                              ...
# 483                         мрт в свао адреса и цены
# 1772                             вао москва мрт цена
# 1333                     мрт позвоночника варшавская
# 1765                                     в мрт химки
# 1763               в москве открытого типа адрес мрт
#
#                                                  phrase  effect       ad_id  \
# 1578                           "семеновский томография"     1.6  2428554717
# 404   "!мрт !на !алексеевской !кулаков !переулок !от...     1.7  2101705366
# 2137                  "!круглосуточный !мрт !в !москве"     1.8  3826704844
# 344                            мрт иваньковское шоссе 3     1.8  2101705307
# 604                  сделать мрт в районе ул лобненская     1.8  2101705540
# ...                                                 ...     ...         ...
# 483                             сделать мрт в свао -где     8.7  2101705467
# 1772                                 в стопы москва мрт     8.8  2428554789
# 1333                               мрт позвоночника вао     9.0  2101706306
# 1765                "в москве открытого типа адрес мрт"     9.0  2428554779
# 1763           в москва сделать томография -где -голова     9.3  2428554777
#
#                                   title  \
# 1578      МРТ центры в Москве. От 2000₽
# 404     МРТ в Москве от 2000₽. Звоните!
# 2137        МРТ круглосуточно. От 2000₽
# 344     МРТ в Москве от 2000₽. Звоните!
# 604       МРТ у метро в Москве от 2000₽
# ...                                 ...
# 483     Сделать МРТ в СВАО Москвы 2000₽
# 1772       МРТ стопы в Москве. От 2000₽
# 1333     МРТ позвоночника в ВАО Москвы!
# 1765  Адрес МРТ открытого типа в Москве
# 1763       Сделайте томографию в Москве
#
#                                                    text  \
# 1578  24 часа. МРТ в день обращения. Консультация вр...
# 404   24 часа. МРТ в день обращения. Консультация вр...
# 2137  24 часа. МРТ в день обращения. Консультация вр...
# 344   24 часа. МРТ в день обращения. Консультация вр...
# 604   24 часа. МРТ в день обращения. Консультация вр...
# ...                                                 ...
# 483   24 часа. МРТ в день обращения. Консультация вр...
# 1772  24 часа. МРТ в день обращения. Консультация вр...
# 1333  24 часа. От 2 000₽. Консультация врача бесплат...
# 1765  24 часа. От 2 000₽. Консультация врача бесплат...
# 1763  24 часа. От 2 000₽. Консультация врача бесплат...
#
#                                                    link  word_count  \
# 1578  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 404   https://awesome-site.ru/?utm_source=yandex&utm...           6
# 2137  https://awesome-site.ru/?utm_source=yandex&utm...           4
# 344   https://awesome-site.ru/?utm_source=yandex&utm...           4
# 604   https://awesome-site.ru/?utm_source=yandex&utm...           6
# ...                                                 ...         ...
# 483   https://awesome-site.ru/?utm_source=yandex&utm...           5
# 1772  https://awesome-site.ru/?utm_source=yandex&utm...           4
# 1333  https://awesome-site.ru/?utm_source=yandex&utm...           3
# 1765  https://awesome-site.ru/?utm_source=yandex&utm...           6
# 1763  https://awesome-site.ru/?utm_source=yandex&utm...           6
#
#       new_words_count    campaign
# 1578                2  8e77a0e565
# 404                 6  7f35591a28
# 2137                4  d96029561c
# 344                 4  7f35591a28
# 604                 6  be97523396
# ...               ...         ...
# 483                 5  3cba0fca70
# 1772                4  41af22f2cc
# 1333                3  5ba2e2d560
# 1765                6  034ada41b6
# 1763                6  88dfb2a17b
#
# [476 rows x 10 columns]

# %% [markdown]
# ### Несколько функций в группировках

# %%
# задаем несколько функций сразу

stats.groupby('campaign').agg(['min', 'max'])['effect'].head()

# %%
# разные метрики для разных столбцов

results = stats.groupby('campaign').agg({'effect': ['min', 'max'], 'power_up': 'mean'})
results.head()

# %% [markdown]
# ### Как обращаться к вложенным столбцам

# %%
results['effect']['max'].head()

# %%
# или даже так
stats.groupby('campaign').agg({'effect': ['min', 'max'], 'power_up': 'mean'})['effect']['max'].head()

# %%
# группировка по нескольким столбцам

stats.groupby(['group', 'campaign']).count().head()

# %%
# максимальное число объявлений в одной группе

stats.groupby(['group', 'campaign']).count().sort_values('phrase', ascending=False).head()
